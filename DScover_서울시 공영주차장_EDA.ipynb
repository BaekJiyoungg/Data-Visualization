# %%
# 구글 마운트 시키기
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# 필요한 모듈 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 서울시 공영주차장 안내정보 불러오기
parking_inf = pd.read_csv('/content/gdrive/MyDrive/2023-1 DScover_스터디_프로젝트/Data/전국주차장정보표준데이터.csv', encoding = 'cp949')
parking_inf

# %%
# 각 열의 정보 파악하기
parking_inf.columns
# Out:
# Index(['주차장관리번호', '주차장명', '주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수',
#        '급지구분', '부제시행구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
#        '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
#        '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '결제방법', '특기사항',
#        '관리기관명', '전화번호', '위도', '경도', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
# 필요없는 열 제거하기 => 주차장관리번호 제거하기
parking_inf = parking_inf.iloc[:, 2:]
parking_inf

# %% [markdown]
# # 결측치 처리하기

# %%
도로명 = parking_inf[parking_inf['소재지도로명주소'].isnull()]
도로명['소재지지번주소'].isnull().sum()
# Out:
# 0

# %%
지번 = parking_inf[parking_inf['소재지지번주소'].isnull()]
지번['소재지도로명주소'].isnull().sum()
# Out:
# 0

# %%
parking_inf.isnull().sum(0)
# Out:
# 주차장구분              0
# 주차장유형              0
# 소재지도로명주소        7048
# 소재지지번주소          958
# 주차구획수              0
# 급지구분               0
# 부제시행구분             0
# 운영요일               0
# 평일운영시작시각           0
# 평일운영종료시각           0
# 토요일운영시작시각          0
# 토요일운영종료시각          0
# 공휴일운영시작시각          0
# 공휴일운영종료시각          0
# 요금정보               0
# 주차기본시간             0
# 주차기본요금          2658
# 추가단위시간          8774
# 추가단위요금          8789
# 1일주차권요금적용시간    10515
# 1일주차권요금         9957
# 월정기권요금         10025
# 결제방법            9915
# 특기사항           11910
# 관리기관명              0
# 전화번호            2424
# 위도              2289
# 경도              2301
# 데이터기준일자            0
# 제공기관코드             0
# 제공기관명              0
# dtype: int64

# %%
# 주소 정리
parking_inf[(parking_inf['소재지도로명주소'].isnull()) & (parking_inf['소재지지번주소'].isnull())]
# Out:
# Empty DataFrame
# Columns: [주차장관리번호, 주차장명, 주차장구분, 주차장유형, 소재지도로명주소, 소재지지번주소, 주차구획수, 급지구분, 부제시행구분, 운영요일, 평일운영시작시각, 평일운영종료시각, 토요일운영시작시각, 토요일운영종료시각, 공휴일운영시작시각, 공휴일운영종료시각, 요금정보, 주차기본시간, 주차기본요금, 추가단위시간, 추가단위요금, 1일주차권요금적용시간, 1일주차권요금, 월정기권요금, 결제방법, 특기사항, 관리기관명, 전화번호, 위도, 경도, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []
#
# [0 rows x 33 columns]

# %%
parking_inf.index.dtype
# Out:
# dtype('int64')

# %%
np.isnan(parking_inf.loc[173]['소재지도로명주소'])
# Out:
# True

# %%
pd.isna(parking_inf.loc[173, '소재지도로명주소'])  is True
# Out:
# True

# %%
data = parking_inf.loc[parking_inf['소재지도로명주소'].isnull()]
data['소재지지번주소']
parking_inf.loc[parking_inf['소재지도로명주소'].isnull(), '소재지도로명주소'] = data['소재지지번주소']

# %%
data2 = parking_inf.loc[parking_inf['소재지지번주소'].isnull()]
data2['소재지도로명주소']
parking_inf.loc[parking_inf['소재지지번주소'].isnull(), '소재지지번주소'] = data2['소재지도로명주소']

# %%
parking_inf.isnull().sum()
# Out:
# 주차장관리번호            0
# 주차장명               0
# 주차장구분              0
# 주차장유형              0
# 소재지도로명주소           0
# 소재지지번주소            0
# 주차구획수              0
# 급지구분               0
# 부제시행구분             0
# 운영요일               0
# 평일운영시작시각           0
# 평일운영종료시각           0
# 토요일운영시작시각          0
# 토요일운영종료시각          0
# 공휴일운영시작시각          0
# 공휴일운영종료시각          0
# 요금정보               0
# 주차기본시간             0
# 주차기본요금          2658
# 추가단위시간          8774
# 추가단위요금          8789
# 1일주차권요금적용시간    10515
# 1일주차권요금         9957
# 월정기권요금         10025
# 결제방법            9915
# 특기사항           11910
# 관리기관명              0
# 전화번호            2424
# 위도              2289
# 경도              2301
# 데이터기준일자            0
# 제공기관코드             0
# 제공기관명              0
# dtype: int64

# %%
parking_inf['제공기관명'].unique()
# Out:
# array(['대전광역시 중구', '광주광역시 동구', '강원도 평창군', '강원도 태백시', '울산광역시', '경기도 시흥시',
#        '경상남도 남해군', '경상남도 의령군', '경기도 김포시', '경상남도 산청군', '부산광역시 영도구',
#        '경상북도 문경시', '경상남도 거제시', '전라남도 광양시', '경상북도 청송군', '경상남도 합천군',
#        '강원도 홍천군', '경상북도 안동시', '광주광역시도시철도공사', '경상북도 김천시', '인천관광공사',
#        '전라북도 익산시', '인천광역시 서구', '전라남도 장성군', '강원도 정선군', '울산광역시 울주군',
#        '부산지방공단스포원', '경기도 광명시', '경상남도 통영시', '경상남도 거창군', '서울특별시 강북구',
#        '경기도 수원시', '강원도 강릉시', '대구광역시 수성구', '강원도 영월군', '경기도 화성시',
#        '경상남도 진주시', '인천광역시미추홀구시설관리공단', '서울특별시금천구시설관리공단', '포항시시설관리공단',
#        '충청남도 보령시', '충청남도 계룡시', '인천교통공사', '충청남도 청양군', '서울특별시 영등포구',
#        '서울특별시 양천구', '경상북도 경산시', '경기도 양평군', '서울특별시 도봉구', '강북구도시관리공단',
#        '전라북도 전주시', '경기도 군포시', '전라남도 순천시', '경기도 남양주시', '인천광역시 계양구',
#        '강원도 양양군', '경상북도 영양군', '울산광역시 동구', '전라남도 담양군', '서울특별시 노원구',
#        '경상북도 영덕군', '경기도 양주시', '광주광역시도시공사', '대구광역시 북구', '충청북도 청주시',
#        '부산광역시 기장군', '충청남도 서산시', '대전광역시', '충청남도 논산시', '인천광역시 남동구',
# ...

# %%
parking_inf[parking_inf['소재지도로명주소'].str.contains('서초')]
# Out:
#             주차장관리번호         주차장명 주차장구분 주차장유형                 소재지도로명주소  \
# 8473   337-2-000023     해남관광호텔 옆    공영    노외      전라남도 해남군 해남읍 서초길 60
# 11964  121-1-000001        반포복개천    공영    노상      서울특별시 서초구 서초중앙로 255
# 11965  121-1-000002  방배복개도로 제1지역    공영    노상        서울특별시 서초구 방배천로 16
# 11966  121-1-000003  방배복개도로 제2지역    공영    노상        서울특별시 서초구 동작대로 68
# 11967  121-1-000004          방배역    공영    노상      서울특별시 서초구 방배로 100-2
# 11968  121-1-000005        방배중앙로    공영    노상     서울특별시 서초구 방배중앙로27길 2
# 11969  121-1-000006        방배사이길    공영    노상        서울특별시 서초구 방배로 248
# 11970  121-2-000001        교대역동측    공영    노외       서울특별시 서초구 서초대로 314
# 11971  121-2-000002     양재시민의숲동측    공영    노외      서울특별시 서초구 강남대로 45-2
# 11972  121-2-000003      청계산근린광장    공영    노외       서울특별시 서초구 청계산로 218
# 11973  121-2-000004         반포서래    공영    노외      서울특별시 서초구 사평대로22길31
# 11977  121-2-000005        청계산청룡    공영    노외     서울특별시 서초구 청계산로15길 31
# ...

# %%
parking_no = parking_inf[parking_inf['소재지도로명주소'].isnull()]
parking_no['소재지지번주소'].isnull().sum(0)
# Out:
# 0

# %%
parking_inf[parking_inf['소재지지번주소'].isnull()]
# Out:
#      주차장구분 주차장유형                      소재지도로명주소 소재지지번주소  주차구획수 급지구분 부제시행구분  \
# 1835    공영    노외   서울특별시 영등포구 영등포로62길 13 (신길동)     NaN     98    5    미시행
# 1836    공영    노외  서울특별시 영등포구 당산로27길 12 (당산동3가)     NaN    190    3    미시행
# 1837    공영    노외         서울특별시 영등포구 가마산로31길 16     NaN    192    5    미시행
# 1838    공영    노외    서울특별시 영등포구 영중로 15 (영등포동4가)     NaN    172    2    미시행
# 1839    공영    노외          서울특별시 영등포구 도신로62길 22     NaN     15    5    미시행
# 1840    공영    노외        서울특별시 영등포구 여의대방로45길 18     NaN     17    5    미시행
# 1843    공영    노외           서울특별시 영등포구 선유동1로 80     NaN     61    3    미시행
# 1844    공영    노외           서울특별시 영등포구 영등포로 405     NaN    143    4    미시행
# 1845    공영    노외         서울특별시 영등포구 국회대로22길 20     NaN    397    2    미시행
# 1856    공영    노외   서울특별시 영등포구 영신로10길 15 (영등포동)     NaN    194    4    미시행
# 1857    공영    노외         서울특별시 영등포구 영등포로 53길28     NaN     34    3    미시행
# 1858    공영    노외      서울특별시 영등포구 버드나루로7길 12-15     NaN     28    4    미시행
# ...

# %%
parking_inf[parking_inf['소재지지번주소'].isnull()].shape
# Out:
# (36, 31)

# %% [markdown]
# # 서울시 다른 데이터로 불러오기

# %%
df = pd.read_csv('/content/gdrive/MyDrive/2023-1 DScover_스터디_프로젝트/Data/서울시 공영주차장 안내 정보.csv', encoding = 'cp949')
df
# Out:
#          주차장코드               주차장명                주소 주차장 종류 주차장 종류명  운영구분  \
# 0      1010089      초안산근린공원주차장(구)       도봉구 창동 24-0     NW  노외 주차장     1
# 1      1012254    마들스타디움(근린공원)(구)     노원구 상계동 770-2     NW  노외 주차장     1
# 2      1013181   마장동(건물) 공영주차장(구)     성동구 마장동 463-2     NW  노외 주차장     1
# 3      1025695        영등포여고 공영(구)    영등포구 신길동 184-3     NW  노외 주차장     1
# 4      1025696       당산근린공원 공영(구)  영등포구 당산동3가 385-0     NW  노외 주차장     1
# ...        ...                ...               ...    ...     ...   ...
# 16408   968503  삼양마을공원지하 공영주차장(구)     강북구 미아동 748-2     NW  노외 주차장     1
# 16409   968514      색동공원 공영주차장(구)      강북구 수유동 49-7     NW  노외 주차장     1
# 16410   980509           비봉주차장(구)     종로구 구기동 139-9     NW  노외 주차장     1
# 16411   984617       신도림역환승주차장(구)       구로구 구로동 1-4     NW  노외 주차장     1
# 16412   984688    구로아트밸리 지하주차장(구)     구로구 구로동 102-0     NW  노외 주차장     1
#
#          운영구분명          전화번호  총 주자면 유무료구분  ... 기본 주차 시간(분 단위) 추가 단위 요금  \
# ...

# %%
df.isnull().sum()
# Out:
# 주차장코드                   0
# 주차장명                    0
# 주소                      0
# 주차장 종류                  0
# 주차장 종류명                 0
# 운영구분                    0
# 운영구분명                   0
# 전화번호                 8092
# 총 주자면                   0
# 유무료구분                   0
# 유무료구분명                  0
# 야간무료개방여부                0
# 야간무료개방여부명               0
# 평일 운영 시작시각(HHMM)        0
# 평일 운영 종료시각(HHMM)        0
# 주말 운영 시작시각(HHMM)        0
# 주말 운영 종료시각(HHMM)        0
# 공휴일 운영 시작시각(HHMM)       0
# 공휴일 운영 종료시각(HHMM)       0
# 최종데이터 동기화 시간            0
# 토요일 유,무료 구분             0
# 토요일 유,무료 구분명            0
# 공휴일 유,무료 구분             0
# 공휴일 유,무료 구분명            0
# 월 정기권 금액              853
# 노상 주차장 관리그룹번호         512
# 기본 주차 요금               13
# 기본 주차 시간(분 단위)         14
# 추가 단위 요금              118
# 추가 단위 시간(분 단위)        118
# 버스 기본 주차 요금            66
# 버스 기본 주차 시간(분 단위)      66
# 버스 추가 단위 시간(분 단위)      66
# 버스 추가 단위 요금            66
# 일 최대 요금               865
# ...

# %%
df[df['주소'].str.contains('마포')]
# Out:
#          주차장코드                 주차장명              주소 주차장 종류 주차장 종류명  운영구분  \
# 297    1247677         양화진 공영주차장(구)  마포구 합정동 139-21     NW  노외 주차장     1
# 298    1247678       망원1-2 공영주차장(구)   마포구 망원동 403-2     NW  노외 주차장     1
# 324    1366575         망원동 공영주차장(시)  마포구 망원동 478-10     NW  노외 주차장     1
# 803    1423651     서강대역 환승 공영주차장(구)   마포구 신수동 93-35     NW  노외 주차장     1
# 4088   1504622         망원 유료 주차장(구)  마포구 망원동 394-79     NS  노상 주차장     1
# ...        ...                  ...             ...    ...     ...   ...
# 15980  1913619  성암로 관광버스 주차허용 구간(시)  마포구 상암동 1695-0     NS  노상 주차장     4
# 15981  1913619  성암로 관광버스 주차허용 구간(시)  마포구 상암동 1695-0     NS  노상 주차장     4
# 15994  1914185     소금나루도서관 공영주차장(구)    마포구 염리동 61-4     NW  노외 주차장     1
# 16362   788447        창천중교 공영주차장(구)   마포구 노고산동 33-1     NW  노외 주차장     1
# 16363   790441          도화 공영주차장(구)   마포구 도화동 557-0     NW  노외 주차장     1
#
#           운영구분명         전화번호  총 주자면 유무료구분  ... 기본 주차 시간(분 단위) 추가 단위 요금  \
# ...
